# %% [markdown]
# # Lecture 08: The "Zinc Alkaline" (Zn/MnO$_2$</sub>) Cell
# ## DRAFT
# ---
# The "Zinc Alkaline" battery generally refers to the following cell configuration:
#
# - Zn Negative Electrode
# - $\gamma/\epsilon$ MnO$_2$ cathode
# - KOH (aq) Typically 6M to 8.9M
#
# The discharge reaction _generally_ proceeds as
#
# $$Zn + 4OH^-\rightarrow   Zn(OH)_4^{2-} + 2e^-$$
#
# $$MnO_2 + H_2O + e^- \rightarrow MnOOH + 2OH^-$$
#
# If this is the case, why isn't this battery rechargeable? This is a tragedy in three parts.

# %% [markdown]
# ## Part 1: The "Cathode" (Gamma Phase Manganese Dioxide)
#
# As our reaction begins, we get
#
#
# $MnO_2 + H_2O + e^- \rightarrow MnOOH + OH^-$ [mn 1]
#
# However, what's to say we stop there? Why should we? So we push further and we try to get
#
# $MnOOH + H_2O + 2e^- \rightarrow Mn(OH)_2 + OH^-$ [mn 2]
#
# That's great, right? Why can't we keep going?
#
#
# Well, when $x$ in $MnOOH_x$ approaches $1$, the follow reaction can become thermodynamically favorable at 'lower' pH's
#
# $2MnOOH \rightarrow Mn_2O_3 (s) + H_2O (l)$ [mn 3]
#
# *But that's not all!*
#
# If we electrochemically react the $MnOOH$ before decomposition reaction [mn 3] occurs, we can realize
#
# $3MnOOH + e^- \rightarrow Mn_3O_4 + OH^- + H_2O $ [mn 4]
#
# *But wait, there's more!*
#
# For each of these phases, there are different crystalline configurations.
#
# ![title](imgs/mno2_heros_journey.png)
#
# If there is one thermodynamically "best" crystal structure, how and why can all of these different configurations exist at the same conditions?
#
#
# And into the readings.
#
# [Rus 2014]
#
# From ~50+ years of using MnO2, we've developed an understanding of the the fundamental unit cells as
#
# ![comparison of r and p](imgs/rus_2014_r_p_comp.png)
#
# So, what does this mean? Well by deconvoluting the XRD pattern we can determine fractions of both:
#
# ![comparison of r and p](imgs/rus_fractions.png)
#
#
#
# Now, let's trying electrochemical cycling the gamma phase using cyclic voltametry. What do we see as function of electrolyte composition?
#
# ![comparison of KOH and LiOH](imgs/rus_fractions.png)
#
# record scratch: how do we read this? -> https://pubs.acs.org/doi/pdf/10.1021/acs.jchemed.7b00361
#
# Back to our program. So now that we understand that cyclic voltametry tells us the (quasi-equilibrium behavior) of a system, how do we interpret these results? Well, now let's cycle the battery in these different electrolytes.
#
# ![comparison of KOH and LiOH](imgs/rus_dQdE.png)
#
#
# We see that there is substantial capacity fade in every case, but the slopes look different as well. This indicates different reaction fading mechanisms.
#
# ![comparison of KOH and LiOH](imgs/rus_cycles.png)
#
#
# So now let's try and see where the reactions take place by overlaying _in operando_ XRD with the electrochemical data...
#
#
# ![comparison of KOH and LiOH](imgs/rus_realtime_XRD.png)
#
# ![comparison of KOH and LiOH](imgs/rus_realtime_XRD_quantified.png)

# %% [markdown]
# ## Part 2: The "Anode" (Zinc Metal)
#
# Upon discharge of the zinc anode, if the electrolyte is in large excess, the previous reaction proceeds:
#
# $Zn + 4OH^-\rightarrow   Zn(OH)_4^{2-} + 2e^-$ [zn 1]
#
# In a practical battery, we'd like to minimize the electrolyte, and in this case as we saturate the electrolyte with $Zn(OH)_4^{2-}$ and the reaction goes to
#
# $Zn + 2OH^-\rightarrow   Zn(OH)_2 + 2e^-$ [zn 2]
#
# The zinc hydroxide is metastable, and generally decomposed to
#
# $Zn(OH)_2 \rightarrow ZnO + H_2O$ [zn 3]
#
# And here our challenges begin.
#
# Into the readings
#
# Understanding where the morhophology comes from
# [Cachet 1991]
# [Desai 2014]
# [Gallaway 2010]
#
# Trying to control it:
# [Gallaway 2013]
# [Parker 2014]
# [Chamoun 2015]

# %% [markdown]
# ## Part 3: Mutually Assured Destruction
#
# But it gets even worse:
#
# In a fully constrained cell:
#
# We run out of water!
# - [Horn 2003]
# - [Bhadra 2015]
#
# We get zinc in the $MnO_2$!
#
# - [Paik 2004]
#
# But we can just limit the extent of discharge, right?
#
# Well....
#
# - [Gallaway 2015]
# - [Gallaway 2016]
#
# But we can do things to fix it....
#
# - [Hertzberg 2016]
